# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ahorros = np.random.randint(100, size=[6])
meses = ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio"]
mapeado = range(len(meses))

arr_pedro = np.random.randint(100, size=[6])
arr_marta = np.random.randint(100, size=[6])
arr_ana= np.random.randint(100, size=[6])



plt.plot(arr_pedro, label="Pedro", color="red", ls="-", lw="5")
plt.plot(arr_marta, label="Marta", color="#0000ff", ls="--", lw="4" )
plt.plot(arr_ana, label="Ana", color="green", ls="-.", lw="3")
plt.xticks(mapeado, meses)
plt.legend(["Aqui"], loc=4)
plt.show()



plt.rcParams["figure.figsize"] = (15,5)

# %%
plt.rcParams["figure.figsize"] = (15,5)

# %%
plt.subplot(1, 3, 1)
plt.plot(arr_pedro, label="Pedro", color="red", ls="-", lw= "8",
  marker = "o", markersize= "2", markerfacecolor="yellow", markeredgecolor="red"       )
plt.xticks(mapeado, meses)
plt.legend()

plt.subplot(1, 3, 2)
plt.plot( arr_marta, label="Marta", color="orange", ls= "-", marker="*")
plt.xticks(mapeado, meses)
plt.legend()

plt.subplot(1, 3, 3)
plt.plot( arr_ana, label="Ana", color="cyan", ls= "-.", marker="*")
plt.xticks(mapeado, meses)
plt.legend()




plt.show()
